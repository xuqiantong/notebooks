# %%
ft_folders = [
"imagenet_1k_50e_triphase_wu1k_l2/",
"imagenet_1k_50e_triphase_wu3k_l2/",
"imagenet_1k_50e_triphase_wu10k_l2/",
"imagenet_1k_50e_triphase_wu1k_cyc/",
"imagenet_1k_50e_triphase_wu3k_cyc/",
"imagenet_1k_50e_triphase_wu10k_cyc/",
"imagenet_1k_50e_triphase_wu3k_l10.07/",
"imagenet_1k_50e_triphase_wu3k_l10.12/",
"imagenet_1k_50e_triphase_wu3k_l10.17/",
"imagenet_1k_50e_triphase_wu3k_l10.22/",
"imagenet_1k_50e_triphase_wu3k_l10.27/",
"imagenet_1k_50e_triphase_wu3k_l10.32/",
    
"scratch_wu3k_l1/",
"scratch_wu3k_l10.07/",
"scratch_wu3k_l10.12/",
"scratch_wu3k_l10.22/",
"scratch_wu3k_l10.27/",
"scratch_wu3k_l10.32/",
"scratch_wu3k_l2/",
"scratch_wu3k_l2_299/",
    
"scratch_l2_t4/",
"scratch_l2_t4_299/",
"scratch_l2_t5/",
"scratch_l2_t5_299/",
"scratch_l2_t6/",
"scratch_l2_t6_299/",
    
"scratch_l1_t1/",
"scratch_l1_t1_299/",
"scratch_l1_t2/",
"scratch_l1_t2_299/",
"scratch_l1_t3/",
"scratch_l1_t3_299/",
"scratch_l1_t4/",
"scratch_l1_t4_299/",
"scratch_l1_t5/",
"scratch_l1_t5_299/",
    
"scratch_l1_t6_nm35/",
"scratch_l1_t6_nm35_299/",
"scratch_l1_t6_nm45/",
"scratch_l1_t6_nm45_299/",
"scratch_l1_t6_nm55/",
"scratch_l1_t6_nm55_299/",
"scratch_l1_t6_nm65/",
"scratch_l1_t6_nm65_299/",
"scratch_l1_t6_nm75/",
"scratch_l1_t6_nm75_299/",
"scratch_l1_t6_nm85/",
"scratch_l1_t6_nm85_299/",
"scratch_l1_t6_nm95/",
"scratch_l1_t6_nm95_299/",
    
"joint_base_vaew0.001/",
"joint_base_vaew0.01/",
"joint_base_vaew0.05/",
"joint_base_vaew0.1/",
"joint_base_vaew0.5/",
"joint_base_vaew1/",
"joint_base_vaew2/",
"joint_base_vaew10/",
    
'scratch_l1_t6_nm100/',
'scratch_l1_t6_nm105/',
'scratch_l1_t6_nm110/',
'scratch_l1_t6_nm115/',
'scratch_l1_t6_nm120/',
'scratch_l1_t6_nm125/',

'joint_base_e200_vaew0.001/',
'joint_base_e200_vaew0.01/',
'joint_base_e200_vaew0.05/',
'joint_base_e200_vaew0.1/',
'joint_base_e200_vaew0.5/',
'joint_base_e200_vaew1/',
'joint_base_e200_vaew10/',
'joint_base_e200_vaew2/',
    
'joint_base_e200_lr1.5e-3/',
'joint_base_e200_lr3e-3/',
'joint_base_e200_lr3e-4/',
'joint_base_e200_lr7.5e-4/',
]

# %%
root = '/checkpoint/qiantong/beit/finetuning'
for folder in ft_folders:
    try:
        with open(f'{root}/{folder}latest') as f:
            line = f.readline()
            last_epoch = line.split('-')[1].strip()

        with open(f'{root}/{folder}log.txt') as f:
            best_acc = 0
            best_epoch = 0
            for i, line in enumerate(f):
                d = eval(line)
                acc = d["test_acc1"]
                if acc > best_acc:
                    best_acc = acc
                    best_epoch = i + 1

        print(f'{folder} {round(best_acc, 2)} {best_epoch}')
#         print(f'{round(best_acc, 2)}')
        
    except:
        print(folder)
# Out:
# imagenet_1k_50e_triphase_wu1k_l2/ 83.66 99
# imagenet_1k_50e_triphase_wu3k_l2/
# imagenet_1k_50e_triphase_wu10k_l2/ 83.61 97
# imagenet_1k_50e_triphase_wu1k_cyc/ 83.66 95
# imagenet_1k_50e_triphase_wu3k_cyc/ 83.19 100
# imagenet_1k_50e_triphase_wu10k_cyc/ 83.55 100
# imagenet_1k_50e_triphase_wu3k_l10.07/ 83.19 100
# imagenet_1k_50e_triphase_wu3k_l10.12/ 83.19 100
# imagenet_1k_50e_triphase_wu3k_l10.17/ 83.19 100
# imagenet_1k_50e_triphase_wu3k_l10.22/
# imagenet_1k_50e_triphase_wu3k_l10.27/
# imagenet_1k_50e_triphase_wu3k_l10.32/ 83.52 95
# scratch_wu3k_l1/ 83.59 392
# scratch_wu3k_l10.07/ 83.58 95
# scratch_wu3k_l10.12/ 78.69 40
# scratch_wu3k_l10.22/ 83.53 98
# scratch_wu3k_l10.27/
# scratch_wu3k_l10.32/ 83.3 99
# scratch_wu3k_l2/
# scratch_wu3k_l2_299/ 83.57 100
# scratch_l2_t4/
# scratch_l2_t4_299/ 83.18 99
# scratch_l2_t5/ 83.67 95
# scratch_l2_t5_299/ 83.53 97
# scratch_l2_t6/
# scratch_l2_t6_299/ 83.5 95
# scratch_l1_t1/
# scratch_l1_t1_299/ 83.44 97
# scratch_l1_t2/
# ...

# %%
ft_folders = [
'_scratch_l1_t6_lr2e-3/',
'_scratch_l1_t5_lr2e-3/',
'_scratch_l1_t4_lr2e-3/',
'_scratch_l1_t3_lr2e-3/',
'_scratch_l1_t2_lr2e-3/',
'_scratch_l1_t1_lr2e-3/',
'',
'_scratch_l1_t6_lr4e-3/',
'_scratch_l1_t5_lr4e-3/',
'_scratch_l1_t4_lr4e-3/',
'_scratch_l1_t3_lr4e-3/',
'_scratch_l1_t2_lr4e-3/',
'_scratch_l1_t1_lr4e-3/',
'',
'_scratch_l1_t6_lr8e-3/',
'_scratch_l1_t5_lr8e-3/',
'_scratch_l1_t4_lr8e-3/',
'_scratch_l1_t3_lr8e-3/',
'_scratch_l1_t2_lr8e-3/',
'_scratch_l1_t1_lr8e-3/',
'',
'_scratch_l1_t6_lr2e-2/',
'_scratch_l1_t5_lr2e-2/',
'_scratch_l1_t4_lr2e-2/',
'_scratch_l1_t3_lr2e-2/',
'_scratch_l1_t2_lr2e-2/',
'_scratch_l1_t1_lr2e-2/',
'',
'_scratch_l1_t6_nm35/',
'_scratch_l1_t6_nm45/',
'_scratch_l1_t6_nm55/',
'_scratch_l1_t6_nm65/',
'_scratch_l1_t6_nm75/',
'_scratch_l1_t6_nm85/',
'_scratch_l1_t6_nm95/',
'_scratch_l1_t6_nm100/',
'_scratch_l1_t6_nm105/',
'_scratch_l1_t6_nm110/',
'_scratch_l1_t6_nm115/',
'_scratch_l1_t6_nm120/',
'_scratch_l1_t6_nm125/',
'',
'_joint_base_vaew0.001/',
'_joint_base_vaew0.01/',
'_joint_base_vaew0.05/',
'_joint_base_vaew0.1/',
'_joint_base_vaew0.5/',
'_joint_base_vaew1/',
'_joint_base_vaew2/',
'_joint_base_vaew10/',
'',
'_scratch_l1_t6_wd0_nm35/',
'_scratch_l1_t6_wd0_nm45/',
'_scratch_l1_t6_wd0_nm55/',
'_scratch_l1_t6_wd0_nm65/',
'_scratch_l1_t6_wd0_nm75/',
'_scratch_l1_t6_wd0_nm85/',
'_scratch_l1_t6_wd0_nm95/',
'_scratch_l1_t6_wd0_nm100/',
'_scratch_l1_t6_wd0_nm105/',
'_scratch_l1_t6_wd0_nm110/',
'_scratch_l1_t6_wd0_nm115/',
'_scratch_l1_t6_wd0_nm120/',
'_scratch_l1_t6_wd0_nm125/',
'',
]

# %%
root = '/checkpoint/qiantong/beit/finetuning/1percent.txt'
for folder in ft_folders:
    if len(folder) == 0:
        print()
        continue
        
    try:
        with open(f'{root}/p1{folder}latest') as f:
            line = f.readline()
            last_epoch = line.split('-')[1].strip()

        with open(f'{root}/p1{folder}log.txt') as f:
            best_acc = 0
            best_epoch = 0
            for i, line in enumerate(f):
                d = eval(line)
                acc = d["test_acc1"]
                if acc > best_acc:
                    best_acc = acc
                    best_epoch = i + 1

#         print(f'{folder} {round(best_acc, 2)} {best_epoch}')
        if best_epoch > 80:
            print(f'{round(best_acc, 2)}')
        else:
            print('-')
        
    except:
#         print(f'{root}/p1_{folder}log.txt')
        print('-')
# Out:
# 42.09
# 42.98
# -
# 42.84
# -
# -
#
# 41.75
# 42.83
# 38.96
# 43.11
# 39.27
# 39.22
#
# 41.44
# 42.3
# 38.6
# 42.8
# 39.65
# 40.06
#
# -
# 40.37
# 37.83
# 41.65
# 38.22
# 39.77
#
# 37.0
# 38.22
# -
# 39.47
# 41.58
# 41.62
# -
# 43.96
# 42.86
# 43.66
# 44.71
# 45.81
# 42.58
#
# 40.87
# 42.38
# 38.54
# 39.28
# 36.54
# 35.6
# 35.78
# 36.09
#
# -
# 38.46
# 39.8
# 39.35
# 41.52
# 41.47
# 44.16
# 44.01
# -
# 43.62
# 44.73
# 45.72
# 42.56

# %%
root = '/checkpoint/qiantong/beit/finetuning/10percent.txt'
for folder in ft_folders:
    if len(folder) == 0:
        print()
        continue
        
    try:
        with open(f'{root}/p10{folder}latest') as f:
            line = f.readline()
            last_epoch = line.split('-')[1].strip()

        with open(f'{root}/p10{folder}log.txt') as f:
            best_acc = 0
            best_epoch = 0
            for i, line in enumerate(f):
                d = eval(line)
                acc = d["test_acc1"]
                if acc > best_acc:
                    best_acc = acc
                    best_epoch = i + 1

#         print(f'{folder} {round(best_acc, 2)} {best_epoch}')
        if best_epoch > 80:
            print(f'{round(best_acc, 2)}')
        else:
            print('-')
        
    except:
#         print(f'{root}/p1_{folder}log.txt')
        print('-')
# Out:
# 70.94
# 71.15
# 70.19
# 71.15
# 69.35
# 69.2
#
# 70.95
# 71.52
# 70.38
# -
# -
# 69.78
#
# 70.6
# 70.99
# -
# 71.39
# 69.86
# -
#
# 69.71
# -
# -
# -
# -
# -
#
# 69.14
# 69.76
# 70.38
# 70.14
# -
# 70.92
# 71.81
# 71.48
# -
# 71.64
# 71.88
# 72.24
# 70.85
#
# 70.83
# 71.3
# 69.74
# 69.82
# -
# -
# -
# -
#
# -
# 69.81
# -
# -
# 71.03
# 70.89
# 71.77
# -
# 71.57
# -
# 71.83
# 72.3
# -

# %%
ft_folders = [
# 'scratch_l1_t3_var0w0.1/',
# 'scratch_l1_t3_var0w0.5/',
# 'scratch_l1_t3_var0w1/',
# 'scratch_l1_t3_var0w10/',
# 'scratch_l1_t3_var0w5/',
# '',
# 'scratch_l1_t3_var1w0.1/',
# 'scratch_l1_t3_var1w0.5/',
# 'scratch_l1_t3_var1w1/',
# 'scratch_l1_t3_var1w10/',
# 'scratch_l1_t3_var1w5/',
# '',
# 'scratch_l1_t3_nm85',
# 'scratch_l1_t3_nm95',
# 'scratch_l1_t3_nm100',
# 'scratch_l1_t3_nm105',
# 'scratch_l1_t3_nm110',
# 'scratch_l1_t3_nm115',
# 'scratch_l1_t3_nm120',
# 'scratch_l1_t3_nm125',
# 'scratch_l1_t3_nm130',
# 'scratch_l1_t3_nm140',
# 'scratch_l1_t3_nm150',
# 'scratch_l1_t3_nm160',
# '',
# 'scratch_l1_t3_dp0',
# 'scratch_l1_t3_dp0_fc',
# 'scratch_l1_t3_fc',
# 'scratch_l1_t3',
# '',
# 'scratch_l1_t1_fc',
# 'scratch_l1_t2_fc',
# 'scratch_l1_t3_fc',
# 'scratch_l1_t4_fc',
# 'scratch_l1_t5_fc',
# 'scratch_l1_t6_fc',
# 'scratch_l1_t7_fc',
# 'scratch_l1_t8_fc',
# '',
# 'scratch_l1_t3_minmpb4',
# 'scratch_l1_t3_minmpb4_maxmpb64',
# 'scratch_l1_t3_minmpb4_maxmpb16',
# 'scratch_l1_t3_minmpb4_maxmpb8',
# 'scratch_l1_t3_minmpb4_maxmpb4',
# '',
# 'scratch_l1_t3_nm120',
# 'scratch_l1_t3_nm120_s41',
# 'scratch_l1_t3_nm120_s43',
# 'scratch_l1_t3_nm120_s41_nomean',
# 'scratch_l1_t3_nm120_s43_nomean',
# 'scratch_l1_t6_nm120',
# 'scratch_l1_t6_nm120_s41',
# 'scratch_l1_t6_nm120_s43',
# 'scratch_l1_t6_nm120_s41_nomean',
# 'scratch_l1_t6_nm120_s43_nomean',
# '',
# 'scratch_bsz4096_t1_nm120',
# 'scratch_bsz4096_t2_nm120',
# 'scratch_bsz4096_t3_nm120',
# 'scratch_bsz4096_t4_nm120',
# 'scratch_bsz4096_t5_nm120',
# 'scratch_bsz4096_t6_nm120',
# 'scratch_bsz4096_t7_nm120',
# 'scratch_bsz4096_t8_nm120',
# 'scratch_bsz4096_t9_nm120',
# '',
# 'scratch_bsz4096_e800_t3_nm120',
# 'scratch_bsz4096_e800_t3_nm120_lr3e3',
# 'scratch_bsz4096_e800_t3_nm120_lr3e3_ftlr2e-3',
# 'scratch_bsz4096_e800_t3_nm120_lr3e3_ftlr1e-3',
# 'scratch_bsz4096_e800_t3_nm120_lr3e3_km',
# 'scratch_bsz4096_e800_t6_nm120',
# 'scratch_bsz4096_e800_t6_nm120_lr3e3',
# 'scratch_bsz4096_e800_t6_nm120_lr3e3_ftlr2e-3',
# 'scratch_bsz4096_e800_t6_nm120_lr3e3_ftlr1e-3',
# 'scratch_bsz4096_e800_t6_nm120_lr3e3_km',
# '',
# 'scratch_t1_nm120',
# 'scratch_t2_nm120',
# 'scratch_l1_t3_nm120_s41',
# 'scratch_t4_nm120',
# 'scratch_t5_nm120',
# 'scratch_l1_t6_nm120',
# 'scratch_t7_nm120',
# 'scratch_t8_nm120',
# '',
# 'scratch_t1_nm120_km',
# 'scratch_t2_nm120_km',
# 'scratch_t3_nm120_km',
# 'scratch_t4_nm120_km',
# 'scratch_t5_nm120_km',
# 'scratch_t6_nm120_km',
# 'scratch_t7_nm120_km',
# 'scratch_t8_nm120_km',
# '',
'scratch_l11_t6_nm120',
'scratch_l12_t6_nm120',
'scratch_l14_t6_nm120',
'scratch_l2_t6_nm120',
'',
'scratch_l1_t6_nm120_augl0',
'scratch_l1_t6_nm120_augl1',
'scratch_l1_t6_nm120_augl2',
'scratch_l1_t6_nm120_augl3',
'scratch_l1_t6_nm120_augl4',
'scratch_l1_t6_nm120',
'',
'scratch_bsz2048_t6_nm120',
'scratch_bsz2048_t6_nm120_vw0.01',
'scratch_bsz2048_t6_nm120_vw0.05',
'scratch_bsz2048_t6_nm120_vw0.1',
'scratch_bsz2048_t6_nm120_vw0.1_vm0.25',
'scratch_bsz2048_t6_nm120_vw0.1_vm0.75',
'scratch_bsz2048_t6_nm120_vw0.1_vm1',
'',
'scratch_bsz4096_e800_t3_nm120_lr3e3',
'scratch_bsz4096_e800_t6_nm120_lr3e3',
'scratch_bsz4096_e800_t6_nm120_tri_lr2e3',
'scratch_bsz4096_e800_t6_nm120_lr2e3_wu40',
'scratch_bsz4096_e800_t6_nm120_lr2e3_wu80',
'',
'scratch_bsz4096_e800_t1_nm120_lr2e3',
'scratch_bsz4096_e800_t2_nm120_lr2e3',
'scratch_bsz4096_e800_t4_nm120_lr2e3',
'scratch_bsz4096_e800_t5_nm120_lr2e3',
'scratch_bsz4096_e800_t6_nm120_lr2e3',
'scratch_bsz4096_e800_t7_nm120_lr2e3',
'',
'scratch_bsz2048_t6_nm120',
'scratch_bsz2048_t6_nm120_minmpb32',
'scratch_bsz2048_t6_nm120_minmpb48',
'scratch_bsz2048_t6_nm120_minmpb64',
'',
'scratch_l11_t6_nm120_p1',
'scratch_l12_t6_nm120_p1',
'scratch_l2_t6_nm120_p1',
'scratch_l12_t6_nm120_p1_wu30_lr2e3',
'scratch_l12_t6_nm120_p1_wu30_lr1e3_tri',
'scratch_l12_t6_nm120_p1_wu30_lr2e3_tri',
'',
'scratch_bsz4096_e800_t6_nm120_lr2e3_l11',
'scratch_bsz4096_e800_t6_nm120_lr2e3_l115',
'scratch_bsz4096_e800_l11_t6_nm120_tri_lr1e3',
'scratch_bsz4096_e800_l11_t6_nm120_tri_lr15e3',
'scratch_bsz4096_e800_l11_t6_nm120_tri_lr1e3_vw001',
'',
'scratch_bsz4096_e800_t6_nm120_lr2e3_l115_p1',
'scratch_bsz4096_e800_t6_nm120_lr2e3_l12_p1',
'scratch_bsz4096_e800_t6_nm120_lr2e3_l125_p1',
'scratch_bsz4096_e800_t6_nm120_lr2e3_l13_p1',
'scratch_bsz4096_e800_l11_t6_nm120_tri_lr1e3_vw001_p1',
'scratch_bsz4096_e800_l11_t6_nm120_tri_lr2e3_vw001_p1',
'scratch_bsz4096_e800_l12_t6_nm120_tri_lr1e3_vw001_p1',
'scratch_bsz4096_e800_l12_t6_nm120_tri_lr2e3_vw001_p1',

# '',
# 'base_t3_e200_mix10',
# 'base_t3_e200_mix50',
# 'base_t3_e200_mix100',
# 'base_t3_e200_mix150',
# 'base_t3_e200_mix200',
# '',
# 'base_t1_e200_mix100',
# 'base_t3_e200_mix100',
# 'base_t2_e200_mix100',
# 'base_t4_e200_mix100',
# 'base_t5_e200_mix100',
# 'base_t6_e200_mix100',
# 'base_t7_e200_mix100',
# 'base_t8_e200_mix100',
# '',
# 'base_t3_e200_mix100_beitl-1/',
# 'base_t3_e200_mix100_beitl-2/',
# 'base_t3_e200_mix100_beitl-3/',
# 'base_t3_e200_mix100_beitl-4/',
# 'base_t3_e200_mix100_beitl-5/',
# 'base_t3_e200_mix100_beitl-6/',
# 'base_t3_e200_mix100_beitl-7/',
# 'base_t3_e200_mix100_beitl-8/',
# 'base_t3_e200_mix100_beitl-9/',
]

# %%
for folder in ft_folders:
    if len(folder) == 0:
        print()
        continue
        
    res = []
    for pct in [100, 10, 1]:
        if pct == 100:
            root = f'/checkpoint/qiantong/beit/finetuning'
        else:
            root = f'/checkpoint/qiantong/beit/finetuning/{pct}percent.txt'
            
        try:
            with open(f'{root}/{folder}/latest') as f:
                line = f.readline()
                last_epoch = line.split('-')[1].strip()

            with open(f'{root}/{folder}/log.txt') as f:
                best_acc = 0
                best_epoch = 0
                for i, line in enumerate(f):
                    d = eval(line)
                    acc = d["test_acc1"]
                    if acc > best_acc:
                        best_acc = acc
                        best_epoch = i + 1

                    
            if best_epoch > 30:
                res.append(f'{round(best_acc, 2)}')
            else:
                res.append('-')

        except:
            res.append('-')
    print('\t'.join(res))
#     print(folder, '\t'.join(res))
# Out:
# 83.82	72.74	47.24
# 83.82	72.52	46.01
# 83.43	-	45.27
# 83.49	71.7	44.96
#
# 83.61	71.7	45.39
# 83.42	70.95	43.54
# 83.44	-	45.42
# 83.47	70.54	42.13
# 83.72	71.81	44.92
# 83.68	-	-
#
# 83.7	71.92	-
# 83.73	71.92	-
# 83.58	71.75	-
# 83.61	71.89	-
# 83.4	71.25	-
# 83.66	71.46	-
# 80.71	71.68	-
#
# -	72.35	45.85
# 83.45	72.03	44.49
# 83.9	73.38	48.89
# 83.91	72.34	-
# 83.88	70.64	-
#
# 82.6	68.03	-
# 83.5	70.89	-
# 83.38	70.5	-
# 83.77	71.81	-
# 83.89	72.2	45.54
# 83.72	71.76	-
#
# 83.7	71.92	-
# 83.45	71.17	-
# 83.61	72.28	-
# 83.62	71.67	-
#
# 83.6	71.93	-
# 83.93	72.85	-
# 83.54	71.76	-
# -	-	-
# -	70.43	-
# -	69.6	-
#
# -	72.53	-
# 83.59	72.55	-
# 83.89	73.76	-
# 84.16	73.53	-
# 83.51	73.79	-
#
# 83.19	72.63	-
# -	-	-
# -	-	-
# -	-	-
# -	-	-
# -	-	-
# -	-	-

# %%
layer_decay=0.65
num_layers = 12

a = list(layer_decay ** (num_layers + 1 - i) for i in range(num_layers + 2))
print(a)
# Out:
# [0.003697205891018715, 0.005688009063105715, 0.008750783174008792, 0.013462743344628911, 0.02071191283789063, 0.03186448128906251, 0.049022278906250015, 0.07541889062500001, 0.11602906250000002, 0.17850625000000003, 0.274625, 0.42250000000000004, 0.65, 1.0]
